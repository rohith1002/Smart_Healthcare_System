# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import utils
import os
# %matplotlib inline

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Input, Dropout,Flatten, Conv2D
from tensorflow.keras.layers import BatchNormalization, Activation, MaxPooling2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.utils import plot_model
from livelossplot import PlotLossesKerasTF
from IPython.display import SVG, Image
from livelossplot.tf_keras import PlotLossesCallback
from livelossplot import PlotLossesKerasTF
import tensorflow as tf
import keras
print("Tensorflow version:", tf.__version__)
# Out:
# Tensorflow version: 2.5.0

# %%
import cv2,os

data_path=r'D:\4-1 project\malaria'
categories=os.listdir(data_path)
labels=[i for i in range(len(categories))]

label_dict=dict(zip(categories,labels))

print(label_dict)
print(categories)
print(labels)
# Out:
# {'no': 0, 'yes': 1}
# ['no', 'yes']
# [0, 1]

# %%
img_size=100
data=[]
target=[]


for category in categories:
    folder_path=os.path.join(data_path,category)
    img_names=os.listdir(folder_path)
        
    for img_name in img_names:
        img_path=os.path.join(folder_path,img_name)
        img=cv2.imread(img_path)

        try:
            gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)           
            #Coverting the image into gray scale
            resized=cv2.resize(gray,(img_size,img_size))
            #resizing the gray scale into 100x100, since we need a fixed common size for all the images in the dataset
            data.append(resized)
            target.append(label_dict[category])
            #appending the image and the label(categorized) into the list (dataset)

        except Exception as e:
            print('Exception:',e)
            #if any exception rasied, the exception will be printed here. And pass to the next image

# %%
import numpy as np

data=np.array(data)/255.0

data=np.reshape(data,(data.shape[0],img_size,img_size,1))
target=np.array(target)

from keras.utils import np_utils

new_target=np_utils.to_categorical(target)

# %%
width,height,depth=100,100,1
num_classes=2
model=Sequential()

model.add(Conv2D(64,(3,3),input_shape=(width,height,depth)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))
#The first CNN layer followed by Relu and MaxPooling layers

model.add(Conv2D(128,(3,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))
#The second convolution layer followed by Relu and MaxPooling layers

model.add(Flatten())
model.add(Dropout(0.5))
#Flatten layer to stack the output convolutions from second convolution layer
model.add(Dense(50,activation='relu'))
#Dense layer of 50 neurons
model.add(Dense(2,activation='softmax'))
print(model.summary())
model.compile(loss='BinaryCrossentropy',optimizer='adam',metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 98, 98, 64)        640
# _________________________________________________________________
# activation (Activation)      (None, 98, 98, 64)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 49, 49, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 49, 49, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 47, 47, 128)       73856
# _________________________________________________________________
# activation_1 (Activation)    (None, 47, 47, 128)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 23, 23, 128)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 23, 23, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 67712)             0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 67712)             0
# _________________________________________________________________
# dense (Dense)                (None, 50)                3385650
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 102
# =================================================================
# Total params: 3,460,248
# Trainable params: 3,460,248
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
import visualkeras
from collections import defaultdict
from PIL import ImageFont
color_map = defaultdict(dict)
color_map[Conv2D]['fill'] = 'yellow'
color_map[MaxPooling2D]['fill'] = 'orange'
color_map[Dense]['fill'] = 'blue'
color_map[Flatten]['fill'] = 'purple'
visualkeras.layered_view(model, legend=True,color_map=color_map)
# Out:
# <PIL.Image.Image image mode=RGBA size=1199x559 at 0x28E13A69C08>

# %%
from tensorflow.keras.utils import plot_model
plot_model(model,show_shapes=False)

# %%
from tensorflow.keras.utils import plot_model
plot_model(model,show_shapes=True)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(data,new_target,test_size=0.3)

# %%
import warnings
warnings.filterwarnings('ignore')
#y_train = np.asarray(y_train).astype('float32').reshape((-1,1))
#checkpoint = ModelCheckpoint('mal-{epoch:03d}.model',monitor='val_loss',verbose=0,save_best_only=True,mode='auto')
history=model.fit(x_train,y_train,epochs=40 ,validation_split=0.1)
# Out:
# Epoch 1/40
# 11/11 [==============================] - 5s 462ms/step - loss: 0.2605 - accuracy: 0.9091 - val_loss: 0.2714 - val_accuracy: 0.8987
# Epoch 2/40
# 11/11 [==============================] - 5s 455ms/step - loss: 0.1671 - accuracy: 0.9394 - val_loss: 0.5962 - val_accuracy: 0.7785
# Epoch 3/40
# 11/11 [==============================] - 5s 466ms/step - loss: 0.1875 - accuracy: 0.9273 - val_loss: 0.2861 - val_accuracy: 0.8987
# Epoch 4/40
# 11/11 [==============================] - 5s 460ms/step - loss: 0.1057 - accuracy: 0.9636 - val_loss: 0.3267 - val_accuracy: 0.8924
# Epoch 5/40
# 11/11 [==============================] - 5s 465ms/step - loss: 0.0712 - accuracy: 0.9788 - val_loss: 0.3302 - val_accuracy: 0.8797
# Epoch 6/40
# 11/11 [==============================] - 5s 470ms/step - loss: 0.0794 - accuracy: 0.9697 - val_loss: 0.1823 - val_accuracy: 0.9430
# Epoch 7/40
# 11/11 [==============================] - 5s 479ms/step - loss: 0.0656 - accuracy: 0.9848 - val_loss: 0.2287 - val_accuracy: 0.9304
# Epoch 8/40
# 11/11 [==============================] - 5s 469ms/step - loss: 0.0437 - accuracy: 0.9879 - val_loss: 0.2914 - val_accuracy: 0.9114
# Epoch 9/40
# 11/11 [==============================] - 5s 474ms/step - loss: 0.0464 - accuracy: 0.9848 - val_loss: 0.2232 - val_accuracy: 0.9304
# Epoch 10/40
# 11/11 [==============================] - 5s 487ms/step - loss: 0.0415 - accuracy: 0.9879 - val_loss: 0.2141 - val_accuracy: 0.9367
# Epoch 11/40
# 11/11 [==============================] - 5s 459ms/step - loss: 0.0215 - accuracy: 0.9939 - val_loss: 0.1784 - val_accuracy: 0.9367
# Epoch 12/40
# 11/11 [==============================] - 5s 495ms/step - loss: 0.0252 - accuracy: 0.9909 - val_loss: 0.2614 - val_accuracy: 0.9177
# Epoch 13/40
# 11/11 [==============================] - 6s 533ms/step - loss: 0.0165 - accuracy: 0.9939 - val_loss: 0.1268 - val_accuracy: 0.9620
# Epoch 14/40
# 11/11 [==============================] - 5s 501ms/step - loss: 0.0222 - accuracy: 0.9939 - val_loss: 0.2793 - val_accuracy: 0.9051
# Epoch 15/40
# 11/11 [==============================] - 5s 478ms/step - loss: 0.0188 - accuracy: 0.9939 - val_loss: 0.2984 - val_accuracy: 0.8987
# Epoch 16/40
# 11/11 [==============================] - 6s 513ms/step - loss: 0.0309 - accuracy: 0.9909 - val_loss: 0.1628 - val_accuracy: 0.9494
# Epoch 17/40
# 11/11 [==============================] - 5s 488ms/step - loss: 0.0227 - accuracy: 0.9939 - val_loss: 0.3390 - val_accuracy: 0.8924
# Epoch 18/40
# 11/11 [==============================] - 5s 465ms/step - loss: 0.0145 - accuracy: 0.9970 - val_loss: 0.1910 - val_accuracy: 0.9430
# Epoch 19/40
# 11/11 [==============================] - 5s 468ms/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 0.2089 - val_accuracy: 0.9430
# Epoch 20/40
# 11/11 [==============================] - 5s 474ms/step - loss: 0.0124 - accuracy: 1.0000 - val_loss: 0.3299 - val_accuracy: 0.8924
# Epoch 21/40
# 11/11 [==============================] - 5s 482ms/step - loss: 0.0200 - accuracy: 0.9970 - val_loss: 0.2542 - val_accuracy: 0.9304
# Epoch 22/40
# 11/11 [==============================] - 5s 470ms/step - loss: 0.0169 - accuracy: 1.0000 - val_loss: 0.3309 - val_accuracy: 0.8987
# Epoch 23/40
# 11/11 [==============================] - 5s 477ms/step - loss: 0.0110 - accuracy: 0.9970 - val_loss: 0.1687 - val_accuracy: 0.9367
# Epoch 24/40
# 11/11 [==============================] - 5s 473ms/step - loss: 0.0192 - accuracy: 0.9939 - val_loss: 0.2676 - val_accuracy: 0.9241
# Epoch 25/40
# 11/11 [==============================] - 5s 464ms/step - loss: 0.0153 - accuracy: 0.9970 - val_loss: 0.2731 - val_accuracy: 0.9051
# Epoch 26/40
# 11/11 [==============================] - 5s 466ms/step - loss: 0.0127 - accuracy: 0.9970 - val_loss: 0.2547 - val_accuracy: 0.9114
# Epoch 27/40
# 11/11 [==============================] - 5s 464ms/step - loss: 0.0118 - accuracy: 0.9970 - val_loss: 0.3959 - val_accuracy: 0.8734
# Epoch 28/40
# 11/11 [==============================] - 5s 473ms/step - loss: 0.0100 - accuracy: 0.9970 - val_loss: 0.3431 - val_accuracy: 0.9114
# Epoch 29/40
# 11/11 [==============================] - 5s 461ms/step - loss: 0.0127 - accuracy: 0.9970 - val_loss: 0.2878 - val_accuracy: 0.9304
# Epoch 30/40
# 11/11 [==============================] - 5s 464ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.3200 - val_accuracy: 0.9177
# Epoch 31/40
# 11/11 [==============================] - 5s 461ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.2995 - val_accuracy: 0.9177
# Epoch 32/40
# 11/11 [==============================] - 5s 475ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.3617 - val_accuracy: 0.9114
# Epoch 33/40
# 11/11 [==============================] - 5s 473ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.2667 - val_accuracy: 0.9304
# Epoch 34/40
# 11/11 [==============================] - 5s 470ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.2667 - val_accuracy: 0.9241
# Epoch 35/40
# 11/11 [==============================] - 5s 465ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.2712 - val_accuracy: 0.9304
# Epoch 36/40
# 11/11 [==============================] - 5s 463ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.3022 - val_accuracy: 0.9304
# Epoch 37/40
# 11/11 [==============================] - 5s 467ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.2753 - val_accuracy: 0.9304
# Epoch 38/40
# 11/11 [==============================] - 6s 569ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.3448 - val_accuracy: 0.9114
# Epoch 39/40
# 11/11 [==============================] - 6s 572ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.3355 - val_accuracy: 0.9051
# Epoch 40/40
# 11/11 [==============================] - 6s 516ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.2129 - val_accuracy: 0.9430

# %%
losses = history.history['loss']
accs = history.history['accuracy']
val_losses = history.history['val_loss']
val_accs = history.history['val_accuracy']
epochs = len(losses)

plt.figure(figsize=(12, 4))
for i, metrics in enumerate(zip([losses, accs], [val_losses, val_accs], ['Loss', 'Accuracy'])):
    plt.subplot(1, 2, i + 1)
    plt.plot(range(epochs), metrics[0], label='Training {}'.format(metrics[2]))
    plt.plot(range(epochs), metrics[1], label='Validation {}'.format(metrics[2]))
    plt.legend()
plt.show()

# %%
model=tf.keras.models.load_model('mal-036.model')

from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import array_to_img
from numpy import asarray
import cv2
img=cv2.imread(r'D:\4-1 project\malaria\yes\C33P1thinF_IMG_20150619_114756a_cell_181.png')
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)           
resized=cv2.resize(gray,(100,100))
r=resized.reshape(1,100,100,1)
model.predict(r)
a=np.argmax(model.predict(r), axis=1)
a
# Out:
# array([1], dtype=int64)
