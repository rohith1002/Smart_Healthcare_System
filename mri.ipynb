# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import utils
import os
# %matplotlib inline

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Input, Dropout,Flatten, Conv2D
from tensorflow.keras.layers import BatchNormalization, Activation, MaxPooling2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.utils import plot_model
from livelossplot import PlotLossesKerasTF
from IPython.display import SVG, Image
from livelossplot.tf_keras import PlotLossesCallback
from livelossplot import PlotLossesKerasTF
import tensorflow as tf
import keras
print("Tensorflow version:", tf.__version__)
# Out:
# Tensorflow version: 2.5.0

# %%
import cv2,os

data_path=r'D:\4-1 project\brain_tumor_dataset'
categories=os.listdir(data_path)
labels=[i for i in range(len(categories))]

label_dict=dict(zip(categories,labels))

print(label_dict)
print(categories)
print(labels)
# Out:
# {'no': 0, 'yes': 1}
# ['no', 'yes']
# [0, 1]

# %%
img_size=100
data=[]
target=[]


for category in categories:
    folder_path=os.path.join(data_path,category)
    img_names=os.listdir(folder_path)
        
    for img_name in img_names:
        img_path=os.path.join(folder_path,img_name)
        img=cv2.imread(img_path)

        try:
            gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)           
            #Coverting the image into gray scale
            resized=cv2.resize(gray,(img_size,img_size))
            #resizing the gray scale into 100x100, since we need a fixed common size for all the images in the dataset
            data.append(resized)
            target.append(label_dict[category])
            #appending the image and the label(categorized) into the list (dataset)

        except Exception as e:
            print('Exception:',e)
            #if any exception rasied, the exception will be printed here. And pass to the next image

# %%
import numpy as np

data=np.array(data)/255.0

data=np.reshape(data,(data.shape[0],img_size,img_size,1))
target=np.array(target)

from keras.utils import np_utils

new_target=np_utils.to_categorical(target)

# %%
width,height,depth=100,100,1
num_classes=2
model=Sequential()

model.add(Conv2D(64,(3,3),input_shape=(width,height,depth)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))
#The first CNN layer followed by Relu and MaxPooling layers

model.add(Conv2D(128,(3,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))
#The second convolution layer followed by Relu and MaxPooling layers

model.add(Flatten())
model.add(Dropout(0.5))
#Flatten layer to stack the output convolutions from second convolution layer
model.add(Dense(50,activation='relu'))
#Dense layer of 50 neurons
model.add(Dense(2,activation='softmax'))
print(model.summary())
model.compile(loss='BinaryCrossentropy',optimizer='adam',metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 98, 98, 64)        640
# _________________________________________________________________
# activation (Activation)      (None, 98, 98, 64)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 49, 49, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 49, 49, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 47, 47, 128)       73856
# _________________________________________________________________
# activation_1 (Activation)    (None, 47, 47, 128)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 23, 23, 128)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 23, 23, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 67712)             0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 67712)             0
# _________________________________________________________________
# dense (Dense)                (None, 50)                3385650
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 102
# =================================================================
# Total params: 3,460,248
# Trainable params: 3,460,248
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
import visualkeras
from collections import defaultdict
from PIL import ImageFont
color_map = defaultdict(dict)
color_map[Conv2D]['fill'] = 'blue'
color_map[MaxPooling2D]['fill'] = 'pink'
color_map[Dense]['fill'] = 'green'
color_map[Flatten]['fill'] = 'purple'
visualkeras.layered_view(model, legend=True,color_map=color_map)
# Out:
# <PIL.Image.Image image mode=RGBA size=1199x559 at 0x1750A29BC48>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(data,new_target,test_size=0.1)

# %%
from tensorflow.keras.utils import plot_model
plot_model(model,show_shapes=False)

# %%
from tensorflow.keras.utils import plot_model
plot_model(model,show_shapes=True)

# %%
import warnings
warnings.filterwarnings('ignore')
#y_train = np.asarray(y_train).astype('float32').reshape((-1,1))
#checkpoint = ModelCheckpoint('mri-{epoch:03d}.model',monitor='val_loss',verbose=0,save_best_only=True,mode='auto')
h=model.fit(data,new_target,epochs=40 ,validation_split=0.2)
# Out:
# Epoch 1/40
# 7/7 [==============================] - 4s 430ms/step - loss: 0.6875 - accuracy: 0.5099 - val_loss: 0.5502 - val_accuracy: 0.8627
# Epoch 2/40
# 7/7 [==============================] - 3s 406ms/step - loss: 0.5804 - accuracy: 0.7327 - val_loss: 0.5144 - val_accuracy: 0.7647
# Epoch 3/40
# 7/7 [==============================] - 3s 419ms/step - loss: 0.5268 - accuracy: 0.7673 - val_loss: 0.5255 - val_accuracy: 0.7647
# Epoch 4/40
# 7/7 [==============================] - 3s 415ms/step - loss: 0.4691 - accuracy: 0.7772 - val_loss: 0.4418 - val_accuracy: 0.8824
# Epoch 5/40
# 7/7 [==============================] - 3s 414ms/step - loss: 0.4414 - accuracy: 0.8267 - val_loss: 0.6764 - val_accuracy: 0.7255
# Epoch 6/40
# 7/7 [==============================] - 3s 417ms/step - loss: 0.3993 - accuracy: 0.8020 - val_loss: 0.3606 - val_accuracy: 0.9020
# Epoch 7/40
# 7/7 [==============================] - 3s 426ms/step - loss: 0.3331 - accuracy: 0.8416 - val_loss: 0.3766 - val_accuracy: 0.9020
# Epoch 8/40
# 7/7 [==============================] - 3s 421ms/step - loss: 0.2827 - accuracy: 0.8812 - val_loss: 0.8230 - val_accuracy: 0.6078
# Epoch 9/40
# 7/7 [==============================] - 3s 429ms/step - loss: 0.2753 - accuracy: 0.8911 - val_loss: 0.2167 - val_accuracy: 0.9412
# Epoch 10/40
# 7/7 [==============================] - 3s 420ms/step - loss: 0.2162 - accuracy: 0.9158 - val_loss: 0.8316 - val_accuracy: 0.7059
# Epoch 11/40
# 7/7 [==============================] - 3s 417ms/step - loss: 0.1998 - accuracy: 0.9208 - val_loss: 0.2902 - val_accuracy: 0.9412
# Epoch 12/40
# 7/7 [==============================] - 3s 422ms/step - loss: 0.1328 - accuracy: 0.9653 - val_loss: 0.3353 - val_accuracy: 0.9020
# Epoch 13/40
# 7/7 [==============================] - 3s 427ms/step - loss: 0.1083 - accuracy: 0.9703 - val_loss: 0.3101 - val_accuracy: 0.9216
# Epoch 14/40
# 7/7 [==============================] - 3s 431ms/step - loss: 0.0627 - accuracy: 0.9901 - val_loss: 0.3141 - val_accuracy: 0.9412
# Epoch 15/40
# 7/7 [==============================] - 3s 417ms/step - loss: 0.0452 - accuracy: 0.9901 - val_loss: 0.3737 - val_accuracy: 0.9020
# Epoch 16/40
# 7/7 [==============================] - 3s 411ms/step - loss: 0.0326 - accuracy: 0.9950 - val_loss: 0.7720 - val_accuracy: 0.7451
# Epoch 17/40
# 7/7 [==============================] - 3s 426ms/step - loss: 0.0355 - accuracy: 0.9950 - val_loss: 0.3997 - val_accuracy: 0.9216
# Epoch 18/40
# 7/7 [==============================] - 3s 421ms/step - loss: 0.0198 - accuracy: 1.0000 - val_loss: 0.3117 - val_accuracy: 0.9216
# Epoch 19/40
# 7/7 [==============================] - 3s 415ms/step - loss: 0.0252 - accuracy: 0.9950 - val_loss: 0.4513 - val_accuracy: 0.8824
# Epoch 20/40
# 7/7 [==============================] - 3s 413ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.5208 - val_accuracy: 0.8431
# Epoch 21/40
# 7/7 [==============================] - 3s 430ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.4910 - val_accuracy: 0.8824
# Epoch 22/40
# 7/7 [==============================] - 3s 414ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.5465 - val_accuracy: 0.8431
# Epoch 23/40
# 7/7 [==============================] - 3s 419ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.5086 - val_accuracy: 0.9020
# Epoch 24/40
# 7/7 [==============================] - 3s 432ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.5612 - val_accuracy: 0.8431
# Epoch 25/40
# 7/7 [==============================] - 3s 414ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.5266 - val_accuracy: 0.8627
# Epoch 26/40
# 7/7 [==============================] - 3s 425ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.5329 - val_accuracy: 0.8431
# Epoch 27/40
# 7/7 [==============================] - 3s 432ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.5454 - val_accuracy: 0.8627
# Epoch 28/40
# 7/7 [==============================] - 3s 415ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.5518 - val_accuracy: 0.8627
# Epoch 29/40
# 7/7 [==============================] - 3s 437ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.4514 - val_accuracy: 0.9216
# Epoch 30/40
# 7/7 [==============================] - 3s 429ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.6915 - val_accuracy: 0.8431
# Epoch 31/40
# 7/7 [==============================] - 3s 419ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.5474 - val_accuracy: 0.8824
# Epoch 32/40
# 7/7 [==============================] - 3s 418ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.4546 - val_accuracy: 0.8824
# Epoch 33/40
# 7/7 [==============================] - 3s 419ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.5471 - val_accuracy: 0.8824
# Epoch 34/40
# 7/7 [==============================] - 3s 423ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.5893 - val_accuracy: 0.8824
# Epoch 35/40
# 7/7 [==============================] - 3s 423ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.7169 - val_accuracy: 0.8431
# Epoch 36/40
# 7/7 [==============================] - 3s 424ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.6541 - val_accuracy: 0.8431
# Epoch 37/40
# 7/7 [==============================] - 3s 456ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.8406 - val_accuracy: 0.8431
# Epoch 38/40
# 7/7 [==============================] - 3s 418ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.6839 - val_accuracy: 0.8431
# Epoch 39/40
# 7/7 [==============================] - 3s 426ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4309 - val_accuracy: 0.9216
# Epoch 40/40
# 7/7 [==============================] - 3s 428ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.7386 - val_accuracy: 0.8431

# %%
losses = h.history['loss']
accs = h.history['accuracy']
val_losses = h.history['val_loss']
val_accs = h.history['val_accuracy']
epochs = len(losses)

plt.figure(figsize=(12, 4))
for i, metrics in enumerate(zip([losses, accs], [val_losses, val_accs], ['Loss', 'Accuracy'])):
    plt.subplot(1, 2, i + 1)
    plt.plot(range(epochs), metrics[0], label='Training {}'.format(metrics[2]))
    plt.plot(range(epochs), metrics[1], label='Validation {}'.format(metrics[2]))
    plt.legend()
plt.show()

# %%
model.save('mri.h5')
